# %%
import pandas as pd
import numpy as np

# %%
data_path = r"D:\Project\NCKH\data\raw\price_data.pkl"
data = pd.read_pickle(data_path)
# Out:
# {datetime.date(2023, 8, 17): {'price': {'TSLA': 219.22000122070312,
#    'AMZN': 133.97999572753906,
#    'MSFT': 312.6887512207031,
#    'NFLX': 403.0}},
#  datetime.date(2023, 8, 18): {'price': {'TSLA': 215.49000549316406,
#    'AMZN': 133.22000122070312,
#    'MSFT': 312.2939758300781,
#    'NFLX': 404.5299987792969}},
#  datetime.date(2023, 8, 21): {'price': {'TSLA': 231.27999877929688,
#    'AMZN': 134.67999267578125,
#    'MSFT': 317.62261962890625,
#    'NFLX': 408.2900085449219}},
#  datetime.date(2023, 8, 22): {'price': {'TSLA': 233.19000244140625,
#    'AMZN': 134.25,
#    'MSFT': 318.19488525390625,
#    'NFLX': 413.1700134277344}},
#  datetime.date(2023, 8, 23): {'price': {'TSLA': 236.86000061035156,
#    'AMZN': 135.52000427246094,
#    'MSFT': 322.67486572265625,
#    'NFLX': 427.54998779296875}},
#  datetime.date(2023, 8, 24): {'price': {'TSLA': 230.0399932861328,
#    'AMZN': 131.83999633789062,
#    'MSFT': 315.7378234863281,
#    'NFLX': 406.92999267578125}},
# ...

# %%
df = pd.DataFrame({
    d:{
        **content["price"]
    }
    for d, content in data.items()
}).T
df
# Out:
#                   TSLA        AMZN        MSFT        NFLX
# 2023-08-17  219.220001  133.979996  312.688751  403.000000
# 2023-08-18  215.490005  133.220001  312.293976  404.529999
# 2023-08-21  231.279999  134.679993  317.622620  408.290009
# 2023-08-22  233.190002  134.250000  318.194885  413.170013
# 2023-08-23  236.860001  135.520004  322.674866  427.549988
# ...                ...         ...         ...         ...
# 2025-04-03  267.279999  178.410004  372.426270  917.049988
# 2025-04-04  239.429993  171.000000  359.180603  855.859985
# 2025-04-07  233.289993  175.259995  357.204224  867.830017
# 2025-04-08  221.860001  170.660004  353.910278  870.400024
# 2025-04-09  272.200012  191.100006  389.774414  945.469971
#
# [413 rows x 4 columns]
